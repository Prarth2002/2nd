# %% [markdown]
# # My jupyter notebook in IBM watson Studio

# %% [markdown]
# __Thomas George Thomas__
#
# Data Scientist

# %% [markdown]
# *I am interested in Data Science because I would love to contribute towards affordable and quality healthcare in the future*

# %% [markdown]
#  __The below should print 'Hello World'__

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# ***You miss 100% of the shots you don't take
#
# - Wayne Gretzky
# - icheal Scott
